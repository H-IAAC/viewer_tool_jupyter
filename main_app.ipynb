# %%
from dash_app import DashApp
# Exemplo de como utilizar
if __name__ == '__main__':
    dash_app = DashApp(config_path='config.yaml')
    dash_app.start()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8059/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
