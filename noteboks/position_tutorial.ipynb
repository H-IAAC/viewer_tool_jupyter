# %%
REPO_ROOT_DIR="../"
import sys,os
sys.path.append(os.path.dirname(REPO_ROOT_DIR))

from dash import dcc, html, Input, Output
from dash import Dash
import dash_player
from librepo.dashboard import DashboardApp
from librepo.layouts import LinearLayout, ConstraintLayout, ComponentWithConstraints, HorizontalLayout, VerticalLayout
# %pwd

# %%
component1 = html.Div(
    "component1",
    id = "component1",
    style = {
        "width": "100px",
        "height": "100px",
        "backgroundColor": "aqua",
        "border": "1px solid black"
    }
)

component2 = html.Div(
    "component2",
    id = "component2",
    style = {
        "width": "200px",
        "height": "100px",
        "backgroundColor": "red",
        "border": "1px solid black"
    }
)

component3 = html.Div(
    "component3",
    id = "component3",
    style = {
        "width": "100px",
        "height": "200px",
        "backgroundColor": "yellow",
        "border": "1px solid black"
    }
)

component4 = html.Div(
    "component4",
    id = "component4",
    style = {
        "width": "300px",
        "height": "300px",
        "backgroundColor": "green",
        "border": "1px solid black"
    }
)

app = Dash(__name__)

app.layout = html.Div([
    component1,
    component2,
    component3,
    component4,
])

if __name__ == '__main__':
    app.run(mode='jupyterlab')

# %%
component11 = html.Div(
    "component11",
    id = "component11",
    style = {
        "width": "100px",
        "height": "100px",
        "backgroundColor": "aqua",
        "border": "1px solid black"
    }
)

component12 = html.Div(
    "component12",
    id = "component12",
    style = {
        "width": "100px",
        "height": "100px",
        "backgroundColor": "aqua",
        "border": "1px solid black"
    }
)

component13 = html.Div(
    "component13",
    id = "component13",
    style = {
        "width": "100px",
        "height": "100px",
        "backgroundColor": "aqua",
        "border": "1px solid black"
    }
)

component14 = html.Div(
    "component14",
    id = "component14",
    style = {
        "width": "100px",
        "height": "100px",
        "backgroundColor": "aqua",
        "border": "1px solid black"
    }
)

component21 = html.Div(
    "component21",
    id = "component21",
    style = {
        "width": "200px",
        "height": "100px",
        "backgroundColor": "red",
        "border": "1px solid black"
    }
)

component22 = html.Div(
    "component22",
    id = "component22",
    style = {
        "width": "200px",
        "height": "100px",
        "backgroundColor": "red",
        "border": "1px solid black"
    }
)

component31 = html.Div(
    "component31",
    id = "component31",
    style = {
        "width": "100px",
        "height": "200px",
        "backgroundColor": "yellow",
        "border": "1px solid black"
    }
)

component32 = html.Div(
    "component32",
    id = "component32",
    style = {
        "width": "100px",
        "height": "200px",
        "backgroundColor": "yellow",
        "border": "1px solid black"
    }
)

component33 = html.Div(
    "component33",
    id = "component33",
    style = {
        "width": "100px",
        "height": "200px",
        "backgroundColor": "yellow",
        "border": "1px solid black"
    }
)

component34 = html.Div(
    "component34",
    id = "component34",
    style = {
        "width": "100px",
        "height": "200px",
        "backgroundColor": "yellow",
        "border": "1px solid black"
    }
)

component35 = html.Div(
    "component35",
    id = "component35",
    style = {
        "width": "100px",
        "height": "200px",
        "backgroundColor": "yellow",
        "border": "1px solid black"
    }
)

component36 = html.Div(
    "component36",
    id = "component36",
    style = {
        "width": "100px",
        "height": "200px",
        "backgroundColor": "yellow",
        "border": "1px solid black"
    }
)

component4 = html.Div(
    "component4",
    id = "component4",
    style = {
        "width": "300px",
        "height": "300px",
        "backgroundColor": "green",
        "border": "1px solid black"
    }
)

# %%
if __name__ == '__main__':
    app = DashboardApp()

    app.add_component(LinearLayout([
        component1, component11, component2, component12, component3, component13, component31, component4
    ], gap=100, align="center"))
    app.add_component(ConstraintLayout([
        ComponentWithConstraints(component14, top_margin=50, left_margin=100),
        ComponentWithConstraints(component32, left_to_left_of=component14, top_to_bottom_of=component14, top_margin=10),
        ComponentWithConstraints(component33, left_to_right_of=component14, top_to_top_of=component14, left_margin=30, top_margin=20),
        ComponentWithConstraints(
            LinearLayout([
            component34, component22, component35, component36
        ], orientation="vertical", width=200, height=400), left_to_right_of=component33, top_to_top_of=component33, left_margin=160, top_margin=20)        
    ]))
    app.run()

# %%
app = Dash(__name__)

app.layout = html.Div([
    HorizontalLayout([
        VerticalLayout([
            component1,
            component2,
            component3,
            component4,
        ]),
        VerticalLayout([
            component11,
            component21,
            component31,
        ]),
    ])
    
])

if __name__ == '__main__':
    app.run(mode='jupyterlab')
